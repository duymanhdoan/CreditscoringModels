# %% [markdown]
# ![](https://i.imgur.com/0AUxkXt.png)
#
# # SF Salaries Exercise
#
# Explore San Francisco city employee salary data.
#
# ## Overview
#
# One way to understand how a city government works is by looking at who it employs and how its employees are compensated. This data contains the names, job title, and compensation for San Francisco city employees on an annual basis from 2011 to 2014.
#
#
#
# Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.
#
# ## Resources
#
# [Pandas API Reference](https://pandas.pydata.org/pandas-docs/stable/api.html)
#
# [NumPy Reference](https://docs.scipy.org/doc/numpy/reference/)
#
# [Visualization with Seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html)

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# **Read `Salaries.csv` as a dataframe called `sal`.**

# %%
link = "https://s3-ap-southeast-1.amazonaws.com/intro-to-ml-minhdh/Salaries.csv"
sal = pd.read_csv(link)

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
sal.head(10)
# Out:
#    Id        EmployeeName  ...         Agency  Status
# 0   1      NATHANIEL FORD  ...  San Francisco     NaN
# 1   2        GARY JIMENEZ  ...  San Francisco     NaN
# 2   3      ALBERT PARDINI  ...  San Francisco     NaN
# 3   4   CHRISTOPHER CHONG  ...  San Francisco     NaN
# 4   5     PATRICK GARDNER  ...  San Francisco     NaN
# 5   6      DAVID SULLIVAN  ...  San Francisco     NaN
# 6   7           ALSON LEE  ...  San Francisco     NaN
# 7   8       DAVID KUSHNER  ...  San Francisco     NaN
# 8   9      MICHAEL MORRIS  ...  San Francisco     NaN
# 9  10  JOANNE HAYES-WHITE  ...  San Francisco     NaN
#
# [10 rows x 13 columns]

# %% [markdown]
# **Use the .info() method to find out how many entries there are.**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay ?**
#
# Keyword: [mean](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.mean.html)

# %%
# Your Code Here
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %% [markdown]
# **What is the lowest and highest amount of BasePay?**
#
# Keyword:
# [min](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.min.html) ,
# [max](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.max.html)

# %%
# Your Code Here
sal['BasePay'].min()
# Out:
# -166.01

# %%
# Your Code Here
sal['BasePay'].max()
# Out:
# 319275.01

# %% [markdown]
# **How about OvertimePay in the dataset? What is the average, lowest, highest amount?**

# %%
# Your Code Here
sal['OvertimePay'].mean()
# Out:
# 5066.059886444622

# %%
# Your Code Here
sal['OvertimePay'].min()
# Out:
# -0.01

# %%
# Your Code Here
sal['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# **What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll).**

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
# Now try to select Employees who have name "GARY JIMENEZ"
# Your Code Here
sal[sal['EmployeeName']=='GARY JIMENEZ']
# Out:
#    Id  EmployeeName  ...         Agency  Status
# 1   2  GARY JIMENEZ  ...  San Francisco     NaN
#
# [1 rows x 13 columns]

# %% [markdown]
# **How much does JOSEPH DRISCOLL make (including benefits)?**

# %%
# Your Code Here
infor = sal[sal['EmployeeName']=='JOSEPH DRISCOLL']
infor
# Out:
#     Id     EmployeeName  ...         Agency  Status
# 24  25  JOSEPH DRISCOLL  ...  San Francisco     NaN
#
# [1 rows x 13 columns]

# %%
infor['TotalPay']
# Out:
# 24    270324.91
# Name: TotalPay, dtype: float64

# %% [markdown]
# **What is the name of highest paid person (including benefits)?**

# %%
# Your Code Here
sal['EmployeeName'] [sal['TotalPayBenefits'].idxmax()]
# Out:
# 'NATHANIEL FORD'

# %%
sal['TotalPayBenefits'].max()
# Out:
# 567595.43

# %% [markdown]
# **What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
# Your Code Here
print(sal['TotalPayBenefits'].min())
sal['EmployeeName'][sal['TotalPayBenefits'].idxmin()]
# Out:
# -618.13
# 'Joe Lopez'

# %% [markdown]
# ### His benefits were negative

# %% [markdown]
# **What was the average (mean) BasePay of all employees per year? (2011-2014) ?**
# Keyword: _groupby_

# %%
sal.groupby(by = ['Year']).mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# **How many unique job titles are there?**
#
# Keyword: _unique, nunique_

# %%
# Your Code Here
print(pd.unique(sal['JobTitle']))
len(pd.unique(sal['JobTitle']))
# Out:
# ['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY'
#  'CAPTAIN III (POLICE DEPARTMENT)' 'WIRE ROPE CABLE MAINTENANCE MECHANIC'
#  ... 'Conversion' 'Cashier 3' 'Not provided']
# 2159

# %% [markdown]
# **What are the top 5 most common jobs?**
#
# Keyword: *value_counts*

# %%
# Your Code Here
sal['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# **How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?)**

# %%
df4 = sal[sal['Year'] == 2013]['JobTitle'].value_counts()
counts = 0
for i in df4: 
  if i == 1: 
    counts +=1 
print(counts)
# Out:
# 202

# %% [markdown]
# **How many people have the word Chief in their job title?**

# %%
# Your Code Here
a = [ ]
a = set(a)
for name in sal['JobTitle']:
  if 'Chief' in name: 
    a.add(name)

print(len(a))
# Out:
# 29

# %% [markdown]
# ## Data Visualization
#
# **Implement seaborn's countplot with x='Year'**

# %%
sns.countplot(x = "Year", data=sal)

# %% [markdown]
# **Implement seaborn's distplot for BasePay of Year 2011**

# %%
sns.distplot(sal[sal["Year"] == 2011]["BasePay"], bins = 30);

# %% [markdown]
# **How about other Year**

# %%
# Your Code Here for 2012
sns.distplot(sal[sal["Year"] == 2012]["BasePay"], bins = 30);

# %%
# Your Code Here for 2013
sns.distplot(sal[sal["Year"] == 2013]["BasePay"], bins = 40);

# %%
# Your Code Here for 2014
sns.distplot(sal[sal["Year"] == 2014]["BasePay"], bins = 50);

# %% [markdown]
# ## Bonus
#
# **Visualize top 5 Jobs with BasePay, Benefits and OvertimePay**
#
# Keyword: *index, isin, groupby, mean, plot*

# %%
df = sal[['BasePay','Benefits','OvertimePay'] ].head(5)
df
# Out:
#      BasePay  Benefits  OvertimePay
# 0  167411.18       NaN         0.00
# 1  155966.02       NaN    245131.88
# 2  212739.13       NaN    106088.18
# 3   77916.00       NaN     56120.71
# 4  134401.60       NaN      9737.00

# %%
sns.distplot(df)

# %%
sal.groupby(['BasePay','Benefits','OvertimePay'] ).mean()
# Out:
#                                        Id  OtherPay  ...  Notes  Status
# BasePay    Benefits OvertimePay                      ...
# -166.01    6.56     249.02        72833.0      0.00  ...    NaN     NaN
# -121.63    5.44     182.70        72866.0      0.00  ...    NaN     NaN
# -109.22    4.32     163.83        72873.0      0.00  ...    NaN     NaN
# -106.60    4.66     159.90        72875.0      0.00  ...    NaN     NaN
# -101.88    4.55     153.08        72879.0      0.00  ...    NaN     NaN
# ...                                   ...       ...  ...    ...     ...
#  313312.52 82319.51 0.00          72932.0      0.00  ...    NaN     NaN
#  313686.01 85431.39 0.00          72927.0  23236.00  ...    NaN     NaN
#  315572.01 82849.66 0.00          72930.0      0.00  ...    NaN     NaN
#  318835.49 89540.23 10712.95     110533.0  60563.54  ...    NaN     NaN
#  319275.01 86533.21 0.00          72926.0  20007.06  ...    NaN     NaN
#
# [108197 rows x 7 columns]

# %%
columns = ['BasePay','Benefits','OvertimePay']
index = range(5)

new_df = pd.DataFrame(sal,index=index, columns=columns)

# %%
new_df
# Out:
#      BasePay  Benefits  OvertimePay
# 0  167411.18       NaN         0.00
# 1  155966.02       NaN    245131.88
# 2  212739.13       NaN    106088.18
# 3   77916.00       NaN     56120.71
# 4  134401.60       NaN      9737.00

# %%
sns.distplot(new_df,bins=40)

# %%
a = sal.groupby(by=columns, axis = 1)
a

# %%
sal
# Out:
#             Id       EmployeeName  ...         Agency  Status
# 0            1     NATHANIEL FORD  ...  San Francisco     NaN
# 1            2       GARY JIMENEZ  ...  San Francisco     NaN
# 2            3     ALBERT PARDINI  ...  San Francisco     NaN
# 3            4  CHRISTOPHER CHONG  ...  San Francisco     NaN
# 4            5    PATRICK GARDNER  ...  San Francisco     NaN
# ...        ...                ...  ...            ...     ...
# 148649  148650      Roy I Tillery  ...  San Francisco     NaN
# 148650  148651       Not provided  ...  San Francisco     NaN
# 148651  148652       Not provided  ...  San Francisco     NaN
# 148652  148653       Not provided  ...  San Francisco     NaN
# 148653  148654          Joe Lopez  ...  San Francisco     NaN
#
# [148654 rows x 13 columns]

# %%
# Your Code Here
## Bonus
new_sal = sal[ ['BasePay','Benefits','OvertimePay']].head(5)
sns.distplot(new_sal, bins = 40 )

# %%
# Your Code Here

# %% [markdown]
# **Fun Fact: Is there a correlation between length of the Job Title string and Salary?**
#
# *Hint: corr()*

# %%
# Your Code Here

# %%
shot_name = ''
shot_name = set(shot_name)
for name in sal['JobTitle']: 
  shot_name.add(len(name))

# %%
df5 = sal[['JobTitle','TotalPay']]
df5
# Out:
#                                               JobTitle   TotalPay
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  567595.43
# 1                      CAPTAIN III (POLICE DEPARTMENT)  538909.28
# 2                      CAPTAIN III (POLICE DEPARTMENT)  335279.91
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC  332343.61
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  326373.19
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# 148650                                    Not provided       0.00
# 148651                                    Not provided       0.00
# 148652                                    Not provided       0.00
# 148653                      Counselor, Log Cabin Ranch    -618.13
#
# [148654 rows x 2 columns]

# %%
for index, text in enumerate(df5['JobTitle']): 
  df5['JobTitle'][index] = len(text)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df5
# Out:
#        JobTitle   TotalPay
# 0            46  567595.43
# 1            31  538909.28
# 2            31  335279.91
# 3            36  332343.61
# 4            44  326373.19
# ...         ...        ...
# 148649        9       0.00
# 148650       12       0.00
# 148651       12       0.00
# 148652       12       0.00
# 148653       26    -618.13
#
# [148654 rows x 2 columns]

# %%
sns.distplot(df5,bins=10)

# %%
sal.groupby(by = sal.EmployeeName , axis = 0)

# %%
sns.distplot(df5['JobTitle'], kde=False);
# plt.axvline(0, color="k");

# %%
Tên càng dài thì thu thập càng khả quan =))

# %% [markdown]
# # Great Job!
